# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#KJW_Final_Project_DS620" data-toc-modified-id="KJW_Final_Project_DS620-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>KJW_Final_Project_DS620</a></span></li><li><span><a href="#Graph-of-the-Class-Groups" data-toc-modified-id="Graph-of-the-Class-Groups-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Graph of the Class Groups</a></span></li><li><span><a href="#Graph-of-the-Class-Discussions" data-toc-modified-id="Graph-of-the-Class-Discussions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Graph of the Class Discussions</a></span></li><li><span><a href="#Prepare-for-Text-Analysis" data-toc-modified-id="Prepare-for-Text-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prepare for Text Analysis</a></span></li><li><span><a href="#Base-Metrics-of-Discussions" data-toc-modified-id="Base-Metrics-of-Discussions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Base Metrics of Discussions</a></span></li><li><span><a href="#Clean-the-Discussions-Data" data-toc-modified-id="Clean-the-Discussions-Data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Clean the Discussions Data</a></span></li><li><span><a href="#Sentiment-Analysis" data-toc-modified-id="Sentiment-Analysis-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Sentiment Analysis</a></span></li><li><span><a href="#Cosine-Similarity-Analysis" data-toc-modified-id="Cosine-Similarity-Analysis-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Cosine Similarity Analysis</a></span></li><li><span><a href="#Inferences-&amp;-Conclusions" data-toc-modified-id="Inferences-&amp;-Conclusions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Inferences &amp; Conclusions</a></span></li><li><span><a href="#Credits" data-toc-modified-id="Credits-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Credits</a></span></li></ul></div>

# %% [markdown]
# ### KJW_Final_Project_DS620

# %%
import networkx as nx
import pandas as pd
import numpy as np
import nltk
from gensim.utils import lemmatize
from nltk.tokenize import word_tokenize, sent_tokenize

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

from nltk import RegexpTokenizer
from nltk.corpus import stopwords
stop = stopwords.words('english')
from textblob import TextBlob

from collections import Counter
import string
import re

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Graph of the Class Groups

# %%
edge_list_1=pd.read_csv('ds620_project_groups.csv',header=0)

# %%
g_project=nx.Graph()
g_project.add_edges_from(zip(edge_list_1['Student1'], edge_list_1['Student2']), label='project_group')

# %%
g_project.nodes()
# Out:
# NodeView(('Vanita Thompson', 'Mael Illien', "Jeremy O'Brien", 'Simon Ustoyev', 'Murat Akyildirim', 'Elina Azrilyan', 'Jack Russo', 'Zachary Alexander', 'Amber Ferger', 'Mikhail Kollontai', 'Subhalaxmi Rout', 'Mia Chen', 'Wei Zhou', 'Habib Khan', 'Priya Shaji', 'Abdellah Ait Elmouden\xa0', 'Vijaya Cherukuri', 'Abdellah Ait Elmouden', 'Sheryl Piechocki', 'Jit Seneviratne', 'Ken Popkin', 'Jagdish Chhabria', 'Willie Smalls'))

# %%
g_project.add_node('Steve Ellington')

# %%
g_project.nodes()
# Out:
# NodeView(('Vanita Thompson', 'Mael Illien', "Jeremy O'Brien", 'Simon Ustoyev', 'Murat Akyildirim', 'Elina Azrilyan', 'Jack Russo', 'Zachary Alexander', 'Amber Ferger', 'Mikhail Kollontai', 'Subhalaxmi Rout', 'Mia Chen', 'Wei Zhou', 'Habib Khan', 'Priya Shaji', 'Abdellah Ait Elmouden\xa0', 'Vijaya Cherukuri', 'Abdellah Ait Elmouden', 'Sheryl Piechocki', 'Jit Seneviratne', 'Ken Popkin', 'Jagdish Chhabria', 'Willie Smalls', 'Steve Ellington'))

# %%
plt.figure(figsize=(8,8))
nx.draw(g_project, with_labels=1)

# %% [markdown]
# ### Graph of the Class Discussions

# %%
#Get the data file of the discussions
discussion_df=pd.read_csv("DS620_Discussion_Board_Data.csv")

# %%
#discussion_df.head()
discussion_df.iloc[1,:]
# Out:
# Thread_Name                                                       Google Ads
# Initial_Post_or_Comment                                                    2
# Author                                                     Zachary Alexander
# Response_To                                                  Vanita Thompson
# Thread_Content             Hi Vanita -- I definitely agree that Google Ad...
# Name: 1, dtype: object

# %%
len(discussion_df)
discussion_df.shape
# Out:
# (181, 5)

# %%
#discussion_df_new=discussion_df[discussion_df.Author!=discussion_df.Response_To]
discussion_df_new=discussion_df[discussion_df.Initial_Post_or_Comment==2]

# %%
discussion_df_new.shape
# Out:
# (98, 5)

# %%
edge_list_2=discussion_df_new.iloc[:,2:4]

# %%
edge_list_2.columns = ["Node1","Node2"]
edge_list_2.shape
# Out:
# (98, 2)

# %%
edge_list_2
# Out:
#                      Node1             Node2
# 1        Zachary Alexander   Vanita Thompson
# 3    Abdellah Ait Elmouden  Vijaya Cherukuri
# 4         Murat Akyildirim  Vijaya Cherukuri
# 5           Jeremy O'Brien  Vijaya Cherukuri
# 7               Ken Popkin       Priya Shaji
# ..                     ...               ...
# 167        Jit Seneviratne  Sheryl Piechocki
# 172             Habib Khan  Vijaya Cherukuri
# 173       Sheryl Piechocki  Vijaya Cherukuri
# 175          Simon Ustoyev        Habib Khan
# 178       Murat Akyildirim     Simon Ustoyev
#
# [98 rows x 2 columns]

# %%
edge_list_new=pd.DataFrame(edge_list_2.groupby(["Node1","Node2"]).size().reset_index(name = "Weight"))
edge_list_new
# Out:
#                     Node1                  Node2  Weight
# 0   Abdellah Ait Elmouden      Mikhail Kollontai       1
# 1   Abdellah Ait Elmouden        Subhalaxmi Rout       1
# 2   Abdellah Ait Elmouden       Vijaya Cherukuri       2
# 3            Amber Ferger  Abdellah Ait Elmouden       1
# 4            Amber Ferger             Jack Russo       1
# ..                    ...                    ...     ...
# 81          Willie Smalls          Simon Ustoyev       2
# 82          Willie Smalls       Steven Ellingson       1
# 83      Zachary Alexander  Abdellah Ait Elmouden       1
# 84      Zachary Alexander            Priya Shaji       1
# 85      Zachary Alexander        Vanita Thompson       2
#
# [86 rows x 3 columns]

# %%
len(edge_list_new)
# Out:
# 86

# %%
g_discussion=nx.Graph()
g_discussion.add_weighted_edges_from(zip(edge_list_new['Node1'], edge_list_new['Node2'], edge_list_new['Weight']),label='discussion_comments')

# %%
plt.figure(figsize=(10,10))
nx.draw(g_discussion, with_labels=1)

# %%
g_discussion.edges(data='weight')
# Out:
# EdgeDataView([('Abdellah Ait Elmouden', 'Mikhail Kollontai', 1), ('Abdellah Ait Elmouden', 'Subhalaxmi Rout', 1), ('Abdellah Ait Elmouden', 'Vijaya Cherukuri', 2), ('Abdellah Ait Elmouden', 'Amber Ferger', 1), ('Abdellah Ait Elmouden', 'Jagdish Chhabria', 1), ('Abdellah Ait Elmouden', "Jeremy O'Brien", 1), ('Abdellah Ait Elmouden', 'Ken Popkin', 2), ('Abdellah Ait Elmouden', 'Murat Akyildirim', 1), ('Abdellah Ait Elmouden', 'Priya Shaji', 1), ('Abdellah Ait Elmouden', 'Zachary Alexander', 1), ('Mikhail Kollontai', 'Elina Azrilyan\xa0', 1), ('Mikhail Kollontai', 'Jagdish Chhabria', 1), ('Mikhail Kollontai', 'Mael Illien', 1), ('Mikhail Kollontai', 'Ken Popkin', 3), ('Mikhail Kollontai', 'Murat Akyildirim', 1), ('Mikhail Kollontai', 'Steven Ellingson', 1), ('Mikhail Kollontai', 'Sheryl Piechocki', 1), ('Mikhail Kollontai', 'Subhalaxmi Rout', 1), ('Subhalaxmi Rout', 'Habib Khan', 1), ('Subhalaxmi Rout', 'Jack Russo', 1), ('Subhalaxmi Rout', 'Jagdish Chhabria', 1), ('Subhalaxmi Rout', 'Mael Illien', 1), ('Subhalaxmi Rout', 'Murat Akyildirim', 1), ('Subhalaxmi Rout', 'Priya Shaji', 1), ('Subhalaxmi Rout', 'Sheryl Piechocki', 1), ('Subhalaxmi Rout', 'Steven Ellingson', 1), ('Subhalaxmi Rout', 'Amber Ferger', 2), ('Subhalaxmi Rout', 'Zachary Alexander', 1), ('Vijaya Cherukuri', 'Habib Khan', 1), ('Vijaya Cherukuri', "Jeremy O'Brien", 1), ('Vijaya Cherukuri', 'Mael Illien', 1), ('Vijaya Cherukuri', 'Murat Akyildirim', 1), ('Vijaya Cherukuri', 'Sheryl Piechocki', 1), ('Vijaya Cherukuri', 'Amber Ferger', 2), ('Vijaya Cherukuri', 'Ken Popkin', 1), ('Vijaya Cherukuri', 'Priya Shaji', 1), ('Amber Ferger', 'Jack Russo', 1), ('Amber Ferger', 'Mael Illien', 1), ('Amber Ferger', 'Steven Ellingson', 1), ('Amber Ferger', 'Vanita Thompson', 1), ('Amber Ferger', 'Jagdish Chhabria', 1), ('Amber Ferger', 'Jit Seneviratne', 1), ('Jack Russo', 'Elina Azrilyan\xa0', 1), ('Jack Russo', 'Habib Khan', 1), ('Jack Russo', 'Ken Popkin', 1), ('Jack Russo', 'Mael Illien', 1), ('Jack Russo', "Jeremy O'Brien", 1), ('Mael Illien', 'Steven Ellingson', 1), ('Steven Ellingson', 'Sheryl Piechocki', 1), ('Steven Ellingson', 'Vanita Thompson', 1), ('Steven Ellingson', 'Willie Smalls', 1), ('Vanita Thompson', 'Simon Ustoyev', 1), ('Vanita Thompson', 'Zachary Alexander', 2), ('Elina Azrilyan\xa0', 'Priya Shaji', 2), ('Priya Shaji', 'Jit Seneviratne', 1), ('Priya Shaji', 'Ken Popkin', 2), ('Priya Shaji', 'Zachary Alexander', 1), ('Habib Khan', 'Murat Akyildirim', 1), ('Habib Khan', 'Simon Ustoyev', 1), ('Murat Akyildirim', 'Ken Popkin', 1), ('Murat Akyildirim', 'Simon Ustoyev', 1), ('Murat Akyildirim', 'Zachary Alexander', 1), ('Ken Popkin', 'Jagdish Chhabria', 1), ('Ken Popkin', 'Jit Seneviratne', 1), ('Ken Popkin', 'Sheryl Piechocki', 2), ('Ken Popkin', 'Willie Smalls', 1), ('Jagdish Chhabria', 'Willie Smalls', 1), ('Willie Smalls', 'Simon Ustoyev', 2), ("Jeremy O'Brien", 'Jit Seneviratne', 1), ("Jeremy O'Brien", 'Zachary Alexander', 1), ('Jit Seneviratne', 'Sheryl Piechocki', 1), ('Zachary Alexander', 'Sheryl Piechocki', 1), ('Mia Chen', 'Simon Ustoyev', 1)])

# %% [markdown]
# ### Prepare for Text Analysis

# %%
#Combine the discussions' titles with the discussions' content
discussion_df['Combined'] = discussion_df[['Thread_Name', 'Thread_Content']].apply(lambda x: ' '.join(x), axis=1)

# %%
discussion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Thread_Name              181 non-null    object
#  1   Initial_Post_or_Comment  181 non-null    int64
#  2   Author                   181 non-null    object
#  3   Response_To              181 non-null    object
#  4   Thread_Content           181 non-null    object
#  5   Combined                 181 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 8.6+ KB

# %%
discussion_df.head(2)
# Out:
#   Thread_Name  Initial_Post_or_Comment             Author      Response_To  \
# 0  Google Ads                        1    Vanita Thompson  Vanita Thompson
# 1  Google Ads                        2  Zachary Alexander  Vanita Thompson
#
#                                       Thread_Content  \
# 0  Google Ads provides analytic reporting on how ...
# 1  Hi Vanita -- I definitely agree that Google Ad...
#
#                                             Combined
# 0  Google Ads Google Ads provides analytic report...
# 1  Google Ads Hi Vanita -- I definitely agree tha...

# %%
#Create dataframe of the columns needed for text analysis
discussion_text=discussion_df.iloc[:,[2,5]]

# %%
#This dataframe has a row for each class member (author) that wrote at least one discussion post, or commented on an 
#existing post. There is one row per author, so an author who wrote 10 discussions and 10 replies has a single row
#that combines all their writing.
discussion_text_new = pd.DataFrame(discussion_text.groupby('Author').agg({'Combined':lambda x: ', '.join(x)}).reset_index())
discussion_text_new.head()
# Out:
#                   Author                                           Combined
# 0  Abdellah Ait Elmouden  Marketing Analytics in Healthcare Right. Data ...
# 1           Amber Ferger  Food Delivery in Sports Stadiums This is a rea...
# 2        Elina Azrilyan   Cambridge Analytica Great example of data used...
# 3             Habib Khan  Marketing analytics in public sector Hello,\r\...
# 4             Jack Russo  Amazon & Recommendation Systems Tying this int...

# %% [markdown]
# ### Base Metrics of Discussions

# %%
#Create a base metrics dataframe that captures some basic statistics (number of words, number of characters, average
#word length, and number of stopwords) about each author's posts
def avg_word_length(combined):
    words = combined.split()
    avg = sum(len(word) for word in words)/len(words)
    return avg

def stop_words_count(combined):
    count = 0
    words = combined.split()
    stop_words = stopwords.words('english')
    
    for w in words:
        if w in stop_words:
            count = count + 1
    
    return count

base_metrics = discussion_text_new

base_metrics = base_metrics.drop(['Combined'], axis=1)

base_metrics['num_words'] = discussion_text_new.Combined.apply(lambda x: len(str(x).split(' ')))

base_metrics['num_chars'] = discussion_text_new.Combined.str.len()

base_metrics['avg_word_length'] = discussion_text_new.Combined.apply(lambda x: avg_word_length(x)) 

stop_words = stopwords.words('english')
base_metrics['stop_words_count'] = discussion_text_new.Combined.apply(lambda x: stop_words_count(x))

base_metrics = base_metrics.sort_values(['num_words'], ascending=False).reset_index(drop=True) 

print('Metrics for each author, sorted in descending order by number of words')
base_metrics.head()
# Out:
# Metrics for each author, sorted in descending order by number of words
#               Author  num_words  num_chars  avg_word_length  stop_words_count
# 0       Amber Ferger       1989      12660         5.312625               766
# 1   Murat Akyildirim       1717      11369         5.476522               572
# 2  Zachary Alexander       1585       9981         5.244668               635
# 3      Simon Ustoyev       1223       7813         5.436303               473
# 4         Ken Popkin       1218       7328         4.979373               452

# %%
#Identify the most frequently occurring words across all the authors posts
everyones_text = ''
for text in discussion_text_new.Combined:
    everyones_text = everyones_text + ' ' + text.lower()

words = everyones_text.split()
words = Counter(words)
common_words = words.most_common(18)
common_words = [entries[0] for entries in common_words]
print(common_words)
# Out:
# ['the', 'to', 'and', 'of', 'a', 'in', 'is', 'that', 'for', 'on', 'are', 'be', 'with', 'i', 'this', 'as', 'can', 'it']

# %% [markdown]
# ### Clean the Discussions Data

# %%
#Functions used below to clean data
def remove_stop_words(inclean):
    stop_words = stopwords.words('english')
    words = inclean.split()
    outclean = ''
    
    for word in words:
        if word not in stop_words:
            outclean = outclean + ' ' + word
    
    return outclean
    
def remove_common_words(inclean):
    words = inclean.split()
    outclean = ''
    
    for word in words:
        if word not in common_words:
            outclean = outclean + ' ' + word
    
    return outclean

def remove_url(inclean):
    outclean = re.sub(r"http\S+", "", inclean) 
    
    return outclean

# %%
#Run each author's text thru the cleaning steps below, then add the cleaned data as a new column (combined_clean) to the
#discussion_new_text dataframe.
cleandf = discussion_text_new

clean_data_list = []
word_token_list = []
sentence_token_list = []

for text in cleandf.Combined:
    clean = text.lower()     #lower case
    
    clean = remove_stop_words(clean) #remove stop words
    
    clean = remove_common_words(clean) #remove the most common words
    
    clean = remove_url(clean)
    
    clean_data_list.append(clean)
    
    #remove punctuation and tokenize by word
    tokenizer = RegexpTokenizer(r'\w+')
    word_tokens = tokenizer.tokenize(clean)
    word_token_list.append(word_tokens)
    
    #remove punctuation and tokenize by sentence
    translator = str.maketrans('', '', string.punctuation)
    sentence_tokens = sent_tokenize(clean)
    sentence_tokens = [s.translate(translator) for s in sentence_tokens] 
    sentence_token_list.append(sentence_tokens)
    
cleandf['combined_clean'] = clean_data_list
cleandf['word_tokens'] = word_token_list
cleandf['sentence_tokens'] = sentence_token_list

# %%
cleandf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Author           22 non-null     object
#  1   Combined         22 non-null     object
#  2   combined_clean   22 non-null     object
#  3   word_tokens      22 non-null     object
#  4   sentence_tokens  22 non-null     object
# dtypes: object(5)
# memory usage: 1008.0+ bytes

# %%
cleandf.to_csv('cleaned_file_for_text_analysis.csv', index=False)

# %% [markdown]
# ### Sentiment Analysis

# %%
#Assess the sentiment of each author's discussions
sentiment_list = []

for text in cleandf.combined_clean:
    sentiment = TextBlob(text).sentiment
    sentiment_list.append(sentiment)

cleandf['sentiment'] = sentiment_list

# %% [markdown]
# ### Cosine Similarity Analysis

# %%
#Compare each author's discussions to all the other authors and output a dataframe of the comparisons
maindf = cleandf[['Author', 'word_tokens']]
maindf = maindf.rename(columns={'Author':'author'})

tempdf = maindf

mcosine_list = []
for mrow in maindf.values:
    mauthor = mrow[0]
    mtext = mrow[1]
    
    tcosine_list = []
    tcosine_list.append(mauthor)
    for trow in tempdf.values:
        tauthor = trow[0]
        ttext = trow[1]
        
        l1 = []
        l2 = []
        
        mset = {w for w in mtext}  
        tset = {w for w in ttext} 
        rvector = mset.union(tset)
        for w in rvector: 
            if w in mset: 
                l1.append(1) 
            else:
                l1.append(0) 
            
            if w in tset:
                l2.append(1) 
            else:
                l2.append(0) 

        c = 0
        # cosine formula  
        for i in range(len(rvector)): 
                c+= l1[i]*l2[i] 
        cosine = round(c / float((sum(l1)*sum(l2))**0.5),3)
        tcosine_list.append(cosine)
        
    mcosine_list.append(tcosine_list)
    
class_list = list(cleandf.Author)
authors_list = ['main'] + class_list
cosinedf = pd.DataFrame(data=mcosine_list, columns=authors_list)

cosinedf.head()
# Out:
#                     main  Abdellah Ait Elmouden  Amber Ferger  \
# 0  Abdellah Ait Elmouden                  1.000         0.231
# 1           Amber Ferger                  0.231         1.000
# 2        Elina Azrilyan                   0.168         0.243
# 3             Habib Khan                  0.168         0.202
# 4             Jack Russo                  0.148         0.207
#
#    Elina Azrilyan   Habib Khan  Jack Russo  Jagdish Chhabria  Jeremy O'Brien  \
# 0            0.168       0.168       0.148             0.201           0.170
# 1            0.243       0.202       0.207             0.255           0.204
# 2            1.000       0.200       0.156             0.199           0.152
# 3            0.200       1.000       0.162             0.201           0.158
# 4            0.156       0.162       1.000             0.192           0.119
#
#    Jit Seneviratne  Ken Popkin  ...  Murat Akyildirim  Priya Shaji  \
# 0            0.171       0.211  ...             0.203        0.214
# 1            0.222       0.218  ...             0.260        0.219
# 2            0.214       0.191  ...             0.224        0.205
# 3            0.186       0.210  ...             0.268        0.169
# 4            0.167       0.165  ...             0.179        0.131
#
#    Sheryl Piechocki  Simon Ustoyev  Steven Ellingson  Subhalaxmi Rout  \
# 0             0.202          0.181             0.184            0.233
# 1             0.280          0.239             0.239            0.274
# 2             0.233          0.206             0.238            0.223
# 3             0.239          0.234             0.251            0.220
# 4             0.188          0.172             0.214            0.186
#
#    Vanita Thompson  Vijaya Cherukuri  Willie Smalls  Zachary Alexander
# 0            0.194             0.184          0.130              0.214
# 1            0.231             0.233          0.189              0.282
# 2            0.211             0.165          0.131              0.242
# 3            0.183             0.204          0.140              0.221
# 4            0.174             0.123          0.108              0.179
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Inferences & Conclusions

# %% [markdown]
# Statistics is using math to make decisions and statements about data drawn from a population.  In this study we have the rare statistical occurrence in which we can make statements about the entire population (our class).  To be respectful of privacy we chose not to call out anyone by name as we share the conclusions below... <br> <br>

# %% [markdown]
# ### Credits

# %% [markdown]
# 1. We used this article from Analytics Vidyha titled [Ultimate Guide to Deal with Text Data](https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/) to identify... <br>
# a. base metrics to describe the data <br>
# b. cleaning recommendations to ensure our data is in a ready state for similarity analysis.
# <br><br>
# 2. This article, [What is Text Similarity in NLP,](https://rxnlp.com/what-is-text-similarity-nlp/#.XxDDZihKg2w) proved helpful for understanding lexical similarity and it's application.
# <br><br>
# 3. This [StackOverflow link](https://stackoverflow.com/questions/24399820/expression-to-remove-url-links-from-twitter-tweet/24399874) enabled a simple regex means to remove URL's.
# <br><br>
# 4. This [geeksforgeeks.org link](https://www.geeksforgeeks.org/python-measure-similarity-between-two-sentences-using-cosine-similarity/) provided a means to calculate cosine similarity
